# %%
# https://www.404bugs.com/details/1079375428891496448
import cv2 as cv
import numpy as np
import pandas as pd
from tqdm import tqdm
import torch, torchvision
from sklearn import metrics
from sklearn.model_selection import train_test_split
from imageai.Detection import ObjectDetection

from datetime import datetime
import pandas as pd
import numpy as np
from sklearn.metrics import f1_score
import lightgbm
import matplotlib.image as mpimg
from sklearn.metrics import f1_score, log_loss
from sklearn.model_selection import StratifiedKFold, KFold

# %%
detector = ObjectDetection()
detector.setModelTypeAsYOLOv3()
detector.setModelPath("./model/yolov3.pt")
detector.loadModel()
# COCO Name
# 'person', 'bicycle', 'car', 'motorbike', 'bus', 'truck', 'traffic light', 'stop sign'
_ = detector.CustomObjects(person=1, bicycle=1, car=1, motorbike=1, bus=1, 
                                        truck=1, traffic_light=1, stop_sign=1)

# %%
def obj_detect(data, path):
    detect_results = []
    for point in tqdm(data):
        map_id = point['id']
        temp = {}
        root_path = path + str(map_id) + '/'
        # y_length, x_length, _ = cv.imread(root_path + f"{point['key_frame']}").shape
        result = [detector.detectObjectsFromImage(input_image=root_path + f"{_frame['frame_name']}") for _frame in point["frames"]]
        temp['id'] = map_id
        temp['frames'] = result
        detect_results.append(temp)
    return detect_results

# %%
def get_obj_data(df, car_list):
    map_id_list=[]
    obj_num_list = []
    car_num_list = []
    percentage_list = []
    pos_max_list = []
    pos_min_list = []
    pos_mean_list = []
    pos_median_list = []
    pos_std_list = []

    for (map_id, frames) in zip(df['id'], df['frames']):
        for item in frames:
            temp_car = np.array([[_['percentage_probability']] + _["box_points"] for _ in item if _["name"] in car_list])
            # print(temp_car)
            if temp_car.shape[0]:
                map_id_list.append(map_id)
                obj_num_list.append(len(item))
                car_num_list.append(temp_car.shape[0])
                percentage_list.append([temp_car[:, 0].mean(), temp_car[:, 0].std(), temp_car[:, 0].max()])
                temp_x = temp_car[:, 1::2].mean(axis=1)
                temp_y = temp_car[:, 2::2].mean(axis=1)
                pos_max_list.append([temp_x.max(), temp_y.max()])
                pos_min_list.append([temp_x.min(), temp_y.min()])
                pos_mean_list.append([temp_x.mean(), temp_y.mean()])
                pos_median_list.append([np.median(temp_x), np.median(temp_y)])
                pos_std_list.append([temp_x.std(), temp_y.std()])

    temp_df = pd.DataFrame({'map_id':map_id_list,
                          'obj_num':obj_num_list,
                          'car_num':car_num_list,
                          })
    temp_df['percent_mean'] = np.array(percentage_list)[:, 0]
    temp_df['percent_std'] = np.array(percentage_list)[:, 1]
    temp_df['percent_max'] = np.array(percentage_list)[:, 2]
    temp_df['posx'] = np.array(pos_mean_list)[:, 0]
    temp_df['posy'] = np.array(pos_mean_list)[:, 1]
    temp_df['posx_max'] = np.array(pos_max_list)[:, 0]
    temp_df['posy_max'] = np.array(pos_max_list)[:, 0]
    temp_df['posx_min'] = np.array(pos_min_list)[:, 0]
    temp_df['posy_min'] = np.array(pos_min_list)[:, 1]
    temp_df['posx_median'] = np.array(pos_median_list)[:, 0]
    temp_df['posy_median'] = np.array(pos_median_list)[:, 1]
    temp_df['posx_std'] = np.array(pos_std_list)[:, 0]
    temp_df['posy_std'] = np.array(pos_std_list)[:, 1]

    temp_df=temp_df.groupby("map_id").agg({"obj_num":["mean","std"],
                                            "car_num":["mean", "std"],
                                            "percent_mean":["mean", "std"],
                                            "percent_std":["mean"],
                                            "percent_max":["mean"],
                                            "posx":["mean"],
                                            "posy":["mean"],
                                            "posx_max":["mean"],
                                            "posy_max":["mean"],
                                            "posx_min":["mean"],
                                            "posy_min":["mean"],
                                            "posx_median":["mean"],
                                            "posy_median":["mean"],
                                            "posx_std":["mean"],
                                            "posy_std":["mean"]
                                        }).reset_index()

    temp_df.columns=['map_id', 'obj_num_mean', 'obj_num_std', 'car_num_mean', 'car_num_std',
                    'percent_mean', 'percent_mean_std', 'percent_std', 'percent_max',
                    'posx', 'posy', 'posx_max', 'posy_max', 'posx_min', 'posy_min', 
                    'posx_median', 'posx_median', 'posx_std', 'posy_std']
    
    return temp_df

# %%
def get_data(df):
    map_id_list=[]
    label=[]
    key_frame_list=[]
    jpg_name_1=[]
    jpg_name_2=[]
    gap_time_1=[]
    gap_time_2=[]
    im_diff_mean=[]
    im_diff_std=[]
    
    for s in list(df.annotations):
        map_id=s["id"]
        map_key=s["key_frame"]
        frames=s["frames"]
        status=s["status"]
        # 解析每个 frame
        for i in range(0,len(frames)-1):
            f=frames[i]
            f_next=frames[i+1]
            """
            im=mpimg.imread(path+img_path+"/"+map_id+"/"+f["frame_name"])
            im_next=mpimg.imread(path+img_path+"/"+map_id+"/"+f_next["frame_name"])
            
            if im.shape==im_next.shape:
                im_diff=im-im_next
            else:
                im_diff=im
            
            im_diff_mean.append(np.mean(im_diff))
            im_diff_std.append(np.std(im_diff))
            """

            map_id_list.append(map_id)
            key_frame_list.append(map_key)
            jpg_name_1.append(f["frame_name"])
            jpg_name_2.append(f_next["frame_name"])
            gap_time_1.append(f["gps_time"])
            gap_time_2.append(f_next["gps_time"])
            label.append(status)
    train_df= pd.DataFrame({
        "map_id":map_id_list,
        "label":label,
        "key_frame":key_frame_list,
        "jpg_name_1":jpg_name_1,
        "jpg_name_2":jpg_name_2,
        "gap_time_1":gap_time_1,
        "gap_time_2":gap_time_2,
        #"im_diff_mean":im_diff_mean,
        #"im_diff_std":im_diff_std,
    })    
    train_df["gap"]=train_df["gap_time_2"]-train_df["gap_time_1"]
    train_df["gap_time_today"]=train_df["gap_time_1"]%(24*3600)
    train_df["hour"]=train_df["gap_time_1"].apply(lambda x:datetime.fromtimestamp(x).hour)
    train_df["minute"]=train_df["gap_time_1"].apply(lambda x:datetime.fromtimestamp(x).minute)
    train_df["day"]=train_df["gap_time_1"].apply(lambda x:datetime.fromtimestamp(x).day)
    train_df["dayofweek"]=train_df["gap_time_1"].apply(lambda x:datetime.fromtimestamp(x).weekday())
    
    train_df["key_frame"]=train_df["key_frame"].apply(lambda x:int(x.split(".")[0]))
    
    train_df=train_df.groupby("map_id").agg({"gap":["mean","std"],
                                             "hour":["mean"],
                                             "minute":["mean"],
                                             "dayofweek":["mean"],
                                             "gap_time_today":["mean","std"],
                                             #"im_diff_mean":["mean","std"],
                                             #"im_diff_std":["mean","std"],
                                             "label":["mean"],
                                            }).reset_index()
    train_df.columns=["map_id","gap_mean","gap_std",
                      "hour_mean","minute_mean","dayofweek_mean","gap_time_today_mean","gap_time_today_std",
                      #"im_diff_mean_mean","im_diff_mean_std","im_diff_std_mean","im_diff_std_std",
                      "label"]
    
    train_df["label"]=train_df["label"].apply(int)
    
    return train_df

# %%
def stacking(clf, train_x, train_y, test_x, clf_name, class_num, columns):
    # predictors = list(tra7in_x.columns)
    # train_x = train_x.values
    # test_x = test_x.values
    predictors = columns
    folds = 5
    seed = 2019
    kf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=seed)

    train = np.zeros((train_x.shape[0], class_num))
    test = np.zeros((test_x.shape[0], class_num))
    test_pre = np.zeros((folds, test_x.shape[0], class_num))
    test_pre_all = np.zeros((folds, test_x.shape[0]))
    cv_scores = []
    f1_scores = []
    cv_rounds = []

    for i, (train_index, test_index) in enumerate(kf.split(train_x, train_y)):
        tr_x = train_x[train_index]
        tr_y = train_y[train_index]
        te_x = train_x[test_index]
        te_y = train_y[test_index]

        if clf_name == "lgb":
            train_matrix = clf.Dataset(tr_x, label=tr_y)
            test_matrix = clf.Dataset(te_x, label=te_y)

            params = {
                'boosting_type': 'gbdt',
                'objective': 'multiclass',
                #'metric': 'None',
                'metric': 'multi_logloss',
                'min_child_weight': 1.5,
                'num_leaves': 2 ** 3-1,
                'lambda_l2': 10,
                'feature_fraction': 0.8,
                'bagging_fraction': 0.8,
                'bagging_freq': 4,
                'learning_rate': 0.05,
                'seed': 2023,
                'nthread': 28,
                'num_class': class_num,
                # 'silent': True,
                'verbose': -1,
            }

            num_round = 4000
            # early_stopping_rounds = 100
            if test_matrix:
                model = clf.train(params, train_matrix, num_round, valid_sets=test_matrix, 
                                #   verbose_eval=50
                                  #feval=acc_score_vali,
                                #   early_stopping_rounds=early_stopping_rounds
                                  )
                print("\n".join(("%s: %.2f" % x) for x in
                                list(sorted(zip(predictors, model.feature_importance("gain")), key=lambda x: x[1],
                                       reverse=True))[:200]
                                ))
                pre = model.predict(te_x, num_iteration=model.best_iteration)
                pred = model.predict(test_x, num_iteration=model.best_iteration)
                train[test_index] = pre
                test_pre[i, :] = pred
                cv_scores.append(log_loss(te_y, pre))
                
                f1_list=f1_score(te_y,np.argmax(pre,axis=1),average=None)
                f1=0.2*f1_list[0]+0.2*f1_list[1]+0.6*f1_list[2]
                
                f1_scores.append(f1)
                cv_rounds.append(model.best_iteration)
                test_pre_all[i, :] = np.argmax(pred, axis=1)

        print("%s now score is:" % clf_name, cv_scores)
        print("%s now f1-score is:" % clf_name, f1_scores)
        print("%s now round is:" % clf_name, cv_rounds)
    test[:] = test_pre.mean(axis=0)
    print("%s_score_list:" % clf_name, cv_scores)
    print("%s_score_mean:" % clf_name, np.mean(cv_scores), np.mean(f1_scores))
    print("%s_score_std:" % clf_name, np.std(cv_scores))
    return train, test, test_pre_all, np.mean(f1_scores)

# %%
def lgb(x_train, y_train, x_valid, columns):
    lgb_train, lgb_test, sb, cv_scores = stacking(lightgbm, x_train, y_train, x_valid, "lgb", 3, columns)
    return lgb_train, lgb_test, sb, cv_scores

# %%
# train_json = pd.read_json('./data/amap_traffic_annotations_train.json')
# train_data_path = './data/amap_traffic_train_0712/'

# train_obj_info = obj_detect(train_json['annotations'], train_data_path)
# import json
# with open('./result/train_obj_detect.json', 'w', encoding='utf-8') as f:
#     json.dump(train_obj_info, f, ensure_ascii=False, indent=2)

# %%
import copy
train_json = pd.read_json('./data/amap_traffic_annotations_train.json')
train_df_0 = copy.deepcopy(get_data(train_json[:]))

# %%
train_obj_df = pd.read_json('./result/train_obj_detect.json', dtype=object)
car_list = ['car', 'bus', 'truck', 'car', 'bus', 'truck']
train_df_1 = get_obj_data(train_obj_df, car_list)

# %%
from torchvision import transforms
from torch.utils.data import DataLoader
import torch, torchvision
import torch.nn as nn

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

data_transforms = transforms.Compose([
        # transforms.Resize(256),
        transforms.Resize(500),
        transforms.CenterCrop(480),
        transforms.ToTensor(),
        transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
    ])


model_conv = torchvision.models.resnext101_32x8d()
num_ftrs = model_conv.fc.in_features
# model_conv.fc = nn.Sequential(nn.Linear(num_ftrs, 256), 
#                               nn.ReLU(), nn.Linear(256, 32),
#                               nn.ReLU(), nn.Linear(32, 3))
model_conv.fc = nn.Sequential(nn.Linear(num_ftrs, 1024), 
                              nn.ReLU(), nn.Linear(1024, 256), 
                              nn.ReLU(), nn.Linear(256, 3))
temp_weights = torch.load('./model/resnext/1.pth')
model_conv.load_state_dict(temp_weights)
model_conv.fc = nn.Sequential(*list(model_conv.fc.children())[:-2])
_ = model_conv.eval().to(device)

# %%
# from torchvision import datasets

# image_datasets = datasets.ImageFolder('./data/amap_frames/', data_transforms)

# dataloaders = DataLoader(image_datasets, batch_size=1, shuffle=False, num_workers=1)
# dataset_sizes = len(image_datasets)

# output_list = []
# for inputs, _ in dataloaders:
#     outputs = model_conv(inputs.to(device))
#     output_list.append(outputs)

# %%
from PIL import Image

imgs = []
with torch.no_grad():
    for item in tqdm(train_json['annotations']):
        map_id = item['id']
        key_frame_name = item['key_frame']
        img = Image.open('./data/amap_traffic_train_0712/' + map_id + '/' + key_frame_name)
        imgs.append(data_transforms(img).unsqueeze(0))

input_data = torch.cat(imgs).to(device)
# Out:
# 100%|██████████| 1500/1500 [00:27<00:00, 54.14it/s]

# %%
output_data_list = []
with torch.no_grad():
    for i in tqdm(range(input_data.shape[0])):
        output_data = model_conv(input_data[i].unsqueeze(0))
        output_data_list.append(output_data.cpu())
# Out:
# 100%|██████████| 1500/1500 [00:58<00:00, 25.54it/s]

# %%
train_df_2 = torch.cat(output_data_list).numpy()
train_df_2 = pd.DataFrame(train_df_2, columns=['fet'+str(i) for i in range(0, 256)])

# %%
train_df = pd.merge(train_df_0, train_df_1, on='map_id', how='outer').fillna(-100000)
train_df = pd.concat([train_df, train_df_2], axis=1)
train_y=train_df["label"]
train_x=copy.deepcopy(train_df.drop(labels=['map_id', 'label'], axis=1))

# %%
from sklearn.preprocessing import Normalizer

my_transfer = Normalizer()
columns = train_x.columns
train_x = my_transfer.fit_transform(train_x)

# %%
# test_json = pd.read_json('./data/amap_traffic_annotations_test.json')
# test_data_path = './data/amap_traffic_test_0712/'

# test_obj_info = obj_detect(test_json['annotations'], test_data_path)
# with open('./result/test_obj_detect.json', 'w', encoding='utf-8') as f:
#     json.dump(test_obj_info, f, ensure_ascii=False, indent=2)

# %%
test_json = pd.read_json('./data/amap_traffic_annotations_test.json')
test_df_0=get_data(test_json[:])
test_obj_df = pd.read_json('./result/test_obj_detect.json', dtype=object)
car_list = ['car', 'bus', 'truck', 'car', 'bus', 'truck']
test_df_1 = get_obj_data(test_obj_df, car_list)

test_df = pd.merge(test_df_0, test_df_1, on='map_id', how='outer').fillna(-100000)

# %%
valid_x = copy.deepcopy(test_df.drop(labels=['map_id', 'label'], axis=1))
# columns = valid_x.columns
valid_x = my_transfer.fit_transform(valid_x)

# %%
lgb_train, lgb_test, sb, m=lgb(train_x, train_y, train_x, columns)
# sub=test_df[["map_id"]].copy()
# sub["pred"]=np.argmax(lgb_test,axis=1)

# result_dic=dict(zip(sub["map_id"],sub["pred"]))
# #保存
# import json
# with open(path+"amap_traffic_annotations_test.json","r") as f:
#     content=f.read()
# content=json.loads(content)
# for i in content["annotations"]:
#     i['status']=result_dic[i["id"]]
# with open(result_path+"sub_%s.json"%m,"w") as f:
#     f.write(json.dumps(content))
# Out:
# [1]	valid_0's multi_logloss: 0.727961
# [2]	valid_0's multi_logloss: 0.713388
# [3]	valid_0's multi_logloss: 0.702494
# [4]	valid_0's multi_logloss: 0.691399
# [5]	valid_0's multi_logloss: 0.677956
# [6]	valid_0's multi_logloss: 0.667051
# [7]	valid_0's multi_logloss: 0.657981
# [8]	valid_0's multi_logloss: 0.646781
# [9]	valid_0's multi_logloss: 0.638022
# [10]	valid_0's multi_logloss: 0.62951
# [11]	valid_0's multi_logloss: 0.620905
# [12]	valid_0's multi_logloss: 0.614224
# [13]	valid_0's multi_logloss: 0.606987
# [14]	valid_0's multi_logloss: 0.601428
# [15]	valid_0's multi_logloss: 0.595159
# [16]	valid_0's multi_logloss: 0.5896
# [17]	valid_0's multi_logloss: 0.584773
# [18]	valid_0's multi_logloss: 0.580405
# [19]	valid_0's multi_logloss: 0.576735
# [20]	valid_0's multi_logloss: 0.573128
# [21]	valid_0's multi_logloss: 0.570067
# [22]	valid_0's multi_logloss: 0.566537
# [23]	valid_0's multi_logloss: 0.56349
# [24]	valid_0's multi_logloss: 0.558785
# [25]	valid_0's multi_logloss: 0.553971
# [26]	valid_0's multi_logloss: 0.550333
# [27]	valid_0's multi_logloss: 0.546372
# [28]	valid_0's multi_logloss: 0.543433
# [29]	valid_0's multi_logloss: 0.541228
# [30]	valid_0's multi_logloss: 0.538443
# [31]	valid_0's multi_logloss: 0.536317
# [32]	valid_0's multi_logloss: 0.534102
# [33]	valid_0's multi_logloss: 0.530993
# [34]	valid_0's multi_logloss: 0.528612
# [35]	valid_0's multi_logloss: 0.526541
# [36]	valid_0's multi_logloss: 0.52319
# [37]	valid_0's multi_logloss: 0.521383
# [38]	valid_0's multi_logloss: 0.519246
# [39]	valid_0's multi_logloss: 0.517357
# [40]	valid_0's multi_logloss: 0.515475
# [41]	valid_0's multi_logloss: 0.514529
# [42]	valid_0's multi_logloss: 0.513269
# [43]	valid_0's multi_logloss: 0.511699
# [44]	valid_0's multi_logloss: 0.510325
# [45]	valid_0's multi_logloss: 0.507946
# [46]	valid_0's multi_logloss: 0.506284
# [47]	valid_0's multi_logloss: 0.504639
# [48]	valid_0's multi_logloss: 0.502434
# [49]	valid_0's multi_logloss: 0.501953
# [50]	valid_0's multi_logloss: 0.50078
# [51]	valid_0's multi_logloss: 0.499961
# [52]	valid_0's multi_logloss: 0.498228
# [53]	valid_0's multi_logloss: 0.496794
# [54]	valid_0's multi_logloss: 0.495347
# [55]	valid_0's multi_logloss: 0.494114
# [56]	valid_0's multi_logloss: 0.492981
# [57]	valid_0's multi_logloss: 0.492413
# [58]	valid_0's multi_logloss: 0.491579
# [59]	valid_0's multi_logloss: 0.490713
# [60]	valid_0's multi_logloss: 0.490863
# [61]	valid_0's multi_logloss: 0.490246
# [62]	valid_0's multi_logloss: 0.489567
# [63]	valid_0's multi_logloss: 0.488786
# [64]	valid_0's multi_logloss: 0.488456
# [65]	valid_0's multi_logloss: 0.488221
# [66]	valid_0's multi_logloss: 0.487592
# [67]	valid_0's multi_logloss: 0.486578
# [68]	valid_0's multi_logloss: 0.485332
# [69]	valid_0's multi_logloss: 0.484256
# [70]	valid_0's multi_logloss: 0.483403
# [71]	valid_0's multi_logloss: 0.483163
# [72]	valid_0's multi_logloss: 0.482632
# [73]	valid_0's multi_logloss: 0.482154
# [74]	valid_0's multi_logloss: 0.481235
# [75]	valid_0's multi_logloss: 0.480673
# [76]	valid_0's multi_logloss: 0.481151
# [77]	valid_0's multi_logloss: 0.480543
# [78]	valid_0's multi_logloss: 0.479676
# [79]	valid_0's multi_logloss: 0.479086
# [80]	valid_0's multi_logloss: 0.478339
# [81]	valid_0's multi_logloss: 0.477701
# [82]	valid_0's multi_logloss: 0.476688
# [83]	valid_0's multi_logloss: 0.47678
# [84]	valid_0's multi_logloss: 0.477037
# [85]	valid_0's multi_logloss: 0.476581
# [86]	valid_0's multi_logloss: 0.476577
# [87]	valid_0's multi_logloss: 0.476717
# [88]	valid_0's multi_logloss: 0.476433
# [89]	valid_0's multi_logloss: 0.476655
# [90]	valid_0's multi_logloss: 0.476629
# [91]	valid_0's multi_logloss: 0.47651
# [92]	valid_0's multi_logloss: 0.476026
# [93]	valid_0's multi_logloss: 0.475512
# [94]	valid_0's multi_logloss: 0.475582
# [95]	valid_0's multi_logloss: 0.474915
# [96]	valid_0's multi_logloss: 0.474276
# [97]	valid_0's multi_logloss: 0.473972
# [98]	valid_0's multi_logloss: 0.473689
# [99]	valid_0's multi_logloss: 0.473436
# [100]	valid_0's multi_logloss: 0.473541
# [101]	valid_0's multi_logloss: 0.473078
# [102]	valid_0's multi_logloss: 0.472752
# [103]	valid_0's multi_logloss: 0.47233
# [104]	valid_0's multi_logloss: 0.471493
# [105]	valid_0's multi_logloss: 0.471231
# [106]	valid_0's multi_logloss: 0.470882
# [107]	valid_0's multi_logloss: 0.470255
# [108]	valid_0's multi_logloss: 0.470028
# [109]	valid_0's multi_logloss: 0.469491
# [110]	valid_0's multi_logloss: 0.469061
# [111]	valid_0's multi_logloss: 0.468988
# [112]	valid_0's multi_logloss: 0.468775
# [113]	valid_0's multi_logloss: 0.467964
# [114]	valid_0's multi_logloss: 0.467792
# [115]	valid_0's multi_logloss: 0.467193
# [116]	valid_0's multi_logloss: 0.466908
# [117]	valid_0's multi_logloss: 0.466946
# [118]	valid_0's multi_logloss: 0.466927
# [119]	valid_0's multi_logloss: 0.466738
# [120]	valid_0's multi_logloss: 0.467094
# [121]	valid_0's multi_logloss: 0.467015
# [122]	valid_0's multi_logloss: 0.466558
# [123]	valid_0's multi_logloss: 0.466547
# [124]	valid_0's multi_logloss: 0.465667
# [125]	valid_0's multi_logloss: 0.466077
# [126]	valid_0's multi_logloss: 0.466195
# [127]	valid_0's multi_logloss: 0.465889
# [128]	valid_0's multi_logloss: 0.465635
# [129]	valid_0's multi_logloss: 0.466349
# [130]	valid_0's multi_logloss: 0.466387
# [131]	valid_0's multi_logloss: 0.466393
# [132]	valid_0's multi_logloss: 0.466368
# [133]	valid_0's multi_logloss: 0.466607
# [134]	valid_0's multi_logloss: 0.466666
# [135]	valid_0's multi_logloss: 0.466356
# [136]	valid_0's multi_logloss: 0.46613
# [137]	valid_0's multi_logloss: 0.466648
# [138]	valid_0's multi_logloss: 0.466869
# [139]	valid_0's multi_logloss: 0.46712
# [140]	valid_0's multi_logloss: 0.467893
# [141]	valid_0's multi_logloss: 0.468421
# [142]	valid_0's multi_logloss: 0.468886
# [143]	valid_0's multi_logloss: 0.469409
# [144]	valid_0's multi_logloss: 0.469581
# [145]	valid_0's multi_logloss: 0.468977
# [146]	valid_0's multi_logloss: 0.468835
# [147]	valid_0's multi_logloss: 0.468533
# [148]	valid_0's multi_logloss: 0.468347
# [149]	valid_0's multi_logloss: 0.468152
# [150]	valid_0's multi_logloss: 0.467414
# [151]	valid_0's multi_logloss: 0.467366
# [152]	valid_0's multi_logloss: 0.46687
# [153]	valid_0's multi_logloss: 0.467363
# [154]	valid_0's multi_logloss: 0.467221
# [155]	valid_0's multi_logloss: 0.467484
# [156]	valid_0's multi_logloss: 0.467453
# [157]	valid_0's multi_logloss: 0.467493
# [158]	valid_0's multi_logloss: 0.467527
# [159]	valid_0's multi_logloss: 0.467644
# [160]	valid_0's multi_logloss: 0.467296
# [161]	valid_0's multi_logloss: 0.467246
# [162]	valid_0's multi_logloss: 0.467187
# [163]	valid_0's multi_logloss: 0.467167
# [164]	valid_0's multi_logloss: 0.466901
# [165]	valid_0's multi_logloss: 0.466867
# [166]	valid_0's multi_logloss: 0.466864
# [167]	valid_0's multi_logloss: 0.467149
# [301]	valid_0's multi_logloss: 0.478144
# [302]	valid_0's multi_logloss: 0.478415
# [303]	valid_0's multi_logloss: 0.478659
# [304]	valid_0's multi_logloss: 0.478569
# [305]	valid_0's multi_logloss: 0.47887
# [306]	valid_0's multi_logloss: 0.479232
# [307]	valid_0's multi_logloss: 0.479332
# [308]	valid_0's multi_logloss: 0.479661
# [309]	valid_0's multi_logloss: 0.48015
# [310]	valid_0's multi_logloss: 0.480454
# [311]	valid_0's multi_logloss: 0.480984
# [312]	valid_0's multi_logloss: 0.481218
# [313]	valid_0's multi_logloss: 0.481367
# [314]	valid_0's multi_logloss: 0.482048
# [315]	valid_0's multi_logloss: 0.482365
# [316]	valid_0's multi_logloss: 0.482246
# [317]	valid_0's multi_logloss: 0.482017
# [318]	valid_0's multi_logloss: 0.482408
# [319]	valid_0's multi_logloss: 0.48328
# [320]	valid_0's multi_logloss: 0.483321
# [321]	valid_0's multi_logloss: 0.483643
# [322]	valid_0's multi_logloss: 0.483397
# [323]	valid_0's multi_logloss: 0.483634
# [324]	valid_0's multi_logloss: 0.483877
# [325]	valid_0's multi_logloss: 0.483863
# [326]	valid_0's multi_logloss: 0.483949
# [327]	valid_0's multi_logloss: 0.483591
# [328]	valid_0's multi_logloss: 0.483593
# [329]	valid_0's multi_logloss: 0.483349
# [330]	valid_0's multi_logloss: 0.483054
# [331]	valid_0's multi_logloss: 0.482818
# [332]	valid_0's multi_logloss: 0.482835
# [333]	valid_0's multi_logloss: 0.483181
# [334]	valid_0's multi_logloss: 0.483629
# [335]	valid_0's multi_logloss: 0.484187
# [336]	valid_0's multi_logloss: 0.484295
# [337]	valid_0's multi_logloss: 0.484319
# [338]	valid_0's multi_logloss: 0.484586
# [339]	valid_0's multi_logloss: 0.484666
# [340]	valid_0's multi_logloss: 0.48489
# [341]	valid_0's multi_logloss: 0.484894
# [342]	valid_0's multi_logloss: 0.485049
# [343]	valid_0's multi_logloss: 0.485209
# [344]	valid_0's multi_logloss: 0.485234
# [345]	valid_0's multi_logloss: 0.485463
# [346]	valid_0's multi_logloss: 0.485386
# [347]	valid_0's multi_logloss: 0.485661
# [348]	valid_0's multi_logloss: 0.485962
# [349]	valid_0's multi_logloss: 0.486365
# [350]	valid_0's multi_logloss: 0.486453
# [351]	valid_0's multi_logloss: 0.486891
# [352]	valid_0's multi_logloss: 0.487252
# [353]	valid_0's multi_logloss: 0.487532
# [354]	valid_0's multi_logloss: 0.487942
# [355]	valid_0's multi_logloss: 0.488491
# [356]	valid_0's multi_logloss: 0.489036
# [357]	valid_0's multi_logloss: 0.489175
# [358]	valid_0's multi_logloss: 0.489502
# [359]	valid_0's multi_logloss: 0.489882
# [360]	valid_0's multi_logloss: 0.490113
# [361]	valid_0's multi_logloss: 0.490145
# [362]	valid_0's multi_logloss: 0.490089
# [363]	valid_0's multi_logloss: 0.489604
# [364]	valid_0's multi_logloss: 0.489264
# [365]	valid_0's multi_logloss: 0.489445
# [366]	valid_0's multi_logloss: 0.489367
# [367]	valid_0's multi_logloss: 0.488989
# [368]	valid_0's multi_logloss: 0.489239
# [369]	valid_0's multi_logloss: 0.48927
# [370]	valid_0's multi_logloss: 0.48944
# [371]	valid_0's multi_logloss: 0.489864
# [372]	valid_0's multi_logloss: 0.490003
# [373]	valid_0's multi_logloss: 0.490382
# [374]	valid_0's multi_logloss: 0.490529
# [375]	valid_0's multi_logloss: 0.490801
# [376]	valid_0's multi_logloss: 0.490743
# [377]	valid_0's multi_logloss: 0.491132
# [378]	valid_0's multi_logloss: 0.491315
# [379]	valid_0's multi_logloss: 0.491569
# [380]	valid_0's multi_logloss: 0.491895
# [381]	valid_0's multi_logloss: 0.492078
# [382]	valid_0's multi_logloss: 0.492507
# [383]	valid_0's multi_logloss: 0.492529
# [384]	valid_0's multi_logloss: 0.492579
# [385]	valid_0's multi_logloss: 0.492655
# [386]	valid_0's multi_logloss: 0.492758
# [387]	valid_0's multi_logloss: 0.49327
# [388]	valid_0's multi_logloss: 0.493722
# [389]	valid_0's multi_logloss: 0.49395
# [390]	valid_0's multi_logloss: 0.494102
# [391]	valid_0's multi_logloss: 0.494378
# [392]	valid_0's multi_logloss: 0.494531
# [393]	valid_0's multi_logloss: 0.49441
# [394]	valid_0's multi_logloss: 0.494587
# [395]	valid_0's multi_logloss: 0.494408
# [396]	valid_0's multi_logloss: 0.494554
# [397]	valid_0's multi_logloss: 0.494414
# [398]	valid_0's multi_logloss: 0.49437
# [399]	valid_0's multi_logloss: 0.494502
# [400]	valid_0's multi_logloss: 0.49456
# [401]	valid_0's multi_logloss: 0.495037
# [402]	valid_0's multi_logloss: 0.495133
# [403]	valid_0's multi_logloss: 0.495641
# [404]	valid_0's multi_logloss: 0.496354
# [405]	valid_0's multi_logloss: 0.49641
# [406]	valid_0's multi_logloss: 0.496444
# [407]	valid_0's multi_logloss: 0.496711
# [408]	valid_0's multi_logloss: 0.496811
# [409]	valid_0's multi_logloss: 0.496626
# [410]	valid_0's multi_logloss: 0.496951
# [411]	valid_0's multi_logloss: 0.49692
# [412]	valid_0's multi_logloss: 0.497452
# [413]	valid_0's multi_logloss: 0.497929
# [414]	valid_0's multi_logloss: 0.498465
# [415]	valid_0's multi_logloss: 0.498845
# [416]	valid_0's multi_logloss: 0.499394
# [417]	valid_0's multi_logloss: 0.499664
# [418]	valid_0's multi_logloss: 0.49985
# [419]	valid_0's multi_logloss: 0.500015
# [420]	valid_0's multi_logloss: 0.500205
# [421]	valid_0's multi_logloss: 0.500618
# [422]	valid_0's multi_logloss: 0.501024
# [423]	valid_0's multi_logloss: 0.501635
# [424]	valid_0's multi_logloss: 0.502176
# [425]	valid_0's multi_logloss: 0.501991
# [426]	valid_0's multi_logloss: 0.501858
# [427]	valid_0's multi_logloss: 0.501745
# [428]	valid_0's multi_logloss: 0.501845
# [429]	valid_0's multi_logloss: 0.502062
# [430]	valid_0's multi_logloss: 0.502189
# [431]	valid_0's multi_logloss: 0.502381
# [432]	valid_0's multi_logloss: 0.50252
# [433]	valid_0's multi_logloss: 0.502947
# [434]	valid_0's multi_logloss: 0.50356
# [435]	valid_0's multi_logloss: 0.50419
# [436]	valid_0's multi_logloss: 0.504632
# [437]	valid_0's multi_logloss: 0.504935
# [438]	valid_0's multi_logloss: 0.505026
# [439]	valid_0's multi_logloss: 0.505284
# [440]	valid_0's multi_logloss: 0.505505
# [441]	valid_0's multi_logloss: 0.505586
# [442]	valid_0's multi_logloss: 0.505668
# [443]	valid_0's multi_logloss: 0.505624
# [444]	valid_0's multi_logloss: 0.505598
# [445]	valid_0's multi_logloss: 0.505618
# [446]	valid_0's multi_logloss: 0.505961
# [447]	valid_0's multi_logloss: 0.50618
# [448]	valid_0's multi_logloss: 0.506437
# [449]	valid_0's multi_logloss: 0.506449
# [450]	valid_0's multi_logloss: 0.506358
# [451]	valid_0's multi_logloss: 0.506462
# [452]	valid_0's multi_logloss: 0.506466
# [453]	valid_0's multi_logloss: 0.50645
# [454]	valid_0's multi_logloss: 0.506432
# [455]	valid_0's multi_logloss: 0.506452
# [456]	valid_0's multi_logloss: 0.506328
# [457]	valid_0's multi_logloss: 0.506453
# [458]	valid_0's multi_logloss: 0.506625
# [459]	valid_0's multi_logloss: 0.506851
# [460]	valid_0's multi_logloss: 0.506907
# [461]	valid_0's multi_logloss: 0.506799
# [462]	valid_0's multi_logloss: 0.507161
# [463]	valid_0's multi_logloss: 0.507138
# [464]	valid_0's multi_logloss: 0.507274
# [465]	valid_0's multi_logloss: 0.506797
# [466]	valid_0's multi_logloss: 0.50667
# [467]	valid_0's multi_logloss: 0.506613
# [468]	valid_0's multi_logloss: 0.506508
# [469]	valid_0's multi_logloss: 0.506638
# [470]	valid_0's multi_logloss: 0.506898
# [471]	valid_0's multi_logloss: 0.506933
# [472]	valid_0's multi_logloss: 0.507104
# [473]	valid_0's multi_logloss: 0.50723
# [474]	valid_0's multi_logloss: 0.507235
# [475]	valid_0's multi_logloss: 0.50733
# [476]	valid_0's multi_logloss: 0.507285
# [477]	valid_0's multi_logloss: 0.507576
# [478]	valid_0's multi_logloss: 0.507721
# [479]	valid_0's multi_logloss: 0.507881
# [480]	valid_0's multi_logloss: 0.508162
# [481]	valid_0's multi_logloss: 0.508388
# [482]	valid_0's multi_logloss: 0.508144
# [483]	valid_0's multi_logloss: 0.508373
# [484]	valid_0's multi_logloss: 0.508652
# [485]	valid_0's multi_logloss: 0.508893
# [486]	valid_0's multi_logloss: 0.508942
# [487]	valid_0's multi_logloss: 0.509163
# [488]	valid_0's multi_logloss: 0.509348
# [489]	valid_0's multi_logloss: 0.509637
# [490]	valid_0's multi_logloss: 0.50975
# [491]	valid_0's multi_logloss: 0.509828
# [492]	valid_0's multi_logloss: 0.509938
# [493]	valid_0's multi_logloss: 0.510192
# [494]	valid_0's multi_logloss: 0.510294
# [495]	valid_0's multi_logloss: 0.510311
# [496]	valid_0's multi_logloss: 0.510496
# [497]	valid_0's multi_logloss: 0.510552
# [498]	valid_0's multi_logloss: 0.510647
# [499]	valid_0's multi_logloss: 0.510965
# [500]	valid_0's multi_logloss: 0.511147
# [501]	valid_0's multi_logloss: 0.511171
# [502]	valid_0's multi_logloss: 0.511354
# [503]	valid_0's multi_logloss: 0.511154
# [504]	valid_0's multi_logloss: 0.511347
# [505]	valid_0's multi_logloss: 0.511484
# [506]	valid_0's multi_logloss: 0.511644
# [507]	valid_0's multi_logloss: 0.511616
# [508]	valid_0's multi_logloss: 0.511678
# [509]	valid_0's multi_logloss: 0.511928
# [510]	valid_0's multi_logloss: 0.512072
# [511]	valid_0's multi_logloss: 0.511906
# [512]	valid_0's multi_logloss: 0.512033
# [513]	valid_0's multi_logloss: 0.512065
# [514]	valid_0's multi_logloss: 0.51223
# [515]	valid_0's multi_logloss: 0.512462
# [516]	valid_0's multi_logloss: 0.5125
# [517]	valid_0's multi_logloss: 0.512819
# [518]	valid_0's multi_logloss: 0.51298
# [519]	valid_0's multi_logloss: 0.513113
# [520]	valid_0's multi_logloss: 0.513313
# [521]	valid_0's multi_logloss: 0.513696
# [522]	valid_0's multi_logloss: 0.51395
# [523]	valid_0's multi_logloss: 0.514188
# [524]	valid_0's multi_logloss: 0.514399
# [525]	valid_0's multi_logloss: 0.514286
# [526]	valid_0's multi_logloss: 0.514363
# [527]	valid_0's multi_logloss: 0.514399
# [528]	valid_0's multi_logloss: 0.514321
# [529]	valid_0's multi_logloss: 0.514395
# [530]	valid_0's multi_logloss: 0.514603
# [531]	valid_0's multi_logloss: 0.514842
# [532]	valid_0's multi_logloss: 0.514966
# [533]	valid_0's multi_logloss: 0.514911
# [534]	valid_0's multi_logloss: 0.514945
# [535]	valid_0's multi_logloss: 0.515113
# [536]	valid_0's multi_logloss: 0.514958
# [537]	valid_0's multi_logloss: 0.515238
# [538]	valid_0's multi_logloss: 0.515321
# [539]	valid_0's multi_logloss: 0.515143
# [540]	valid_0's multi_logloss: 0.515259
# [541]	valid_0's multi_logloss: 0.515336
# [542]	valid_0's multi_logloss: 0.515418
# [543]	valid_0's multi_logloss: 0.515351
# [544]	valid_0's multi_logloss: 0.515632
# [545]	valid_0's multi_logloss: 0.515929
# [546]	valid_0's multi_logloss: 0.516149
# [547]	valid_0's multi_logloss: 0.51646
# [548]	valid_0's multi_logloss: 0.516602
# [549]	valid_0's multi_logloss: 0.516572
# [550]	valid_0's multi_logloss: 0.516519
# [551]	valid_0's multi_logloss: 0.516624
# [552]	valid_0's multi_logloss: 0.516476
# [553]	valid_0's multi_logloss: 0.516456
# [554]	valid_0's multi_logloss: 0.516726
# [555]	valid_0's multi_logloss: 0.516893
# [556]	valid_0's multi_logloss: 0.516778
# [557]	valid_0's multi_logloss: 0.516712
# [558]	valid_0's multi_logloss: 0.516772
# [559]	valid_0's multi_logloss: 0.516834
# [560]	valid_0's multi_logloss: 0.516731
# [561]	valid_0's multi_logloss: 0.516786
# [562]	valid_0's multi_logloss: 0.516769
# [563]	valid_0's multi_logloss: 0.516762
# [564]	valid_0's multi_logloss: 0.516767
# [565]	valid_0's multi_logloss: 0.516746
# [566]	valid_0's multi_logloss: 0.516866
# [567]	valid_0's multi_logloss: 0.516808
# [568]	valid_0's multi_logloss: 0.516877
# [569]	valid_0's multi_logloss: 0.516973
# [570]	valid_0's multi_logloss: 0.517161
# [571]	valid_0's multi_logloss: 0.517253
# [572]	valid_0's multi_logloss: 0.517479
# [573]	valid_0's multi_logloss: 0.517744
# [574]	valid_0's multi_logloss: 0.517706
# [575]	valid_0's multi_logloss: 0.517916
# [576]	valid_0's multi_logloss: 0.518271
# [577]	valid_0's multi_logloss: 0.518381
# [578]	valid_0's multi_logloss: 0.518517
# [579]	valid_0's multi_logloss: 0.51847
# [580]	valid_0's multi_logloss: 0.518589
# [581]	valid_0's multi_logloss: 0.518886
# [582]	valid_0's multi_logloss: 0.519213
# [583]	valid_0's multi_logloss: 0.519516
# [584]	valid_0's multi_logloss: 0.519556
# [585]	valid_0's multi_logloss: 0.519669
# [586]	valid_0's multi_logloss: 0.519792
# [587]	valid_0's multi_logloss: 0.519969
# [588]	valid_0's multi_logloss: 0.520094
# [589]	valid_0's multi_logloss: 0.52024
# [590]	valid_0's multi_logloss: 0.520384
# [591]	valid_0's multi_logloss: 0.520504
# [592]	valid_0's multi_logloss: 0.520787
# [593]	valid_0's multi_logloss: 0.520992
# [594]	valid_0's multi_logloss: 0.521173
# [595]	valid_0's multi_logloss: 0.521317
# [596]	valid_0's multi_logloss: 0.521433
# [597]	valid_0's multi_logloss: 0.52139
# [598]	valid_0's multi_logloss: 0.52158
# [599]	valid_0's multi_logloss: 0.521626
# [600]	valid_0's multi_logloss: 0.521586
# [601]	valid_0's multi_logloss: 0.521659
# [602]	valid_0's multi_logloss: 0.521812
# [603]	valid_0's multi_logloss: 0.521852
# [604]	valid_0's multi_logloss: 0.521939
# [605]	valid_0's multi_logloss: 0.522071
# [606]	valid_0's multi_logloss: 0.522107
# [607]	valid_0's multi_logloss: 0.522226
# [608]	valid_0's multi_logloss: 0.522272
# [609]	valid_0's multi_logloss: 0.522435
# [610]	valid_0's multi_logloss: 0.522324
# [611]	valid_0's multi_logloss: 0.522256
# [612]	valid_0's multi_logloss: 0.522316
# [613]	valid_0's multi_logloss: 0.522624
# [614]	valid_0's multi_logloss: 0.522633
# [615]	valid_0's multi_logloss: 0.522835
# [616]	valid_0's multi_logloss: 0.522981
# [617]	valid_0's multi_logloss: 0.523199
# [618]	valid_0's multi_logloss: 0.523365
# [619]	valid_0's multi_logloss: 0.523289
# [620]	valid_0's multi_logloss: 0.523487
# [621]	valid_0's multi_logloss: 0.523334
# [622]	valid_0's multi_logloss: 0.523292
# [623]	valid_0's multi_logloss: 0.523357
# [624]	valid_0's multi_logloss: 0.523235
# [625]	valid_0's multi_logloss: 0.523362
# [626]	valid_0's multi_logloss: 0.523316
# [627]	valid_0's multi_logloss: 0.523453
# [628]	valid_0's multi_logloss: 0.523984
# [629]	valid_0's multi_logloss: 0.524013
# [630]	valid_0's multi_logloss: 0.523978
# [631]	valid_0's multi_logloss: 0.523936
# [632]	valid_0's multi_logloss: 0.523917
# [633]	valid_0's multi_logloss: 0.524133
# [634]	valid_0's multi_logloss: 0.524326
# [635]	valid_0's multi_logloss: 0.524579
# [636]	valid_0's multi_logloss: 0.524683
# [637]	valid_0's multi_logloss: 0.524713
# [638]	valid_0's multi_logloss: 0.524831
# [639]	valid_0's multi_logloss: 0.525073
# [640]	valid_0's multi_logloss: 0.525207
# [641]	valid_0's multi_logloss: 0.525283
# [642]	valid_0's multi_logloss: 0.52538
# [643]	valid_0's multi_logloss: 0.525416
# [644]	valid_0's multi_logloss: 0.52544
# [645]	valid_0's multi_logloss: 0.525481
# [646]	valid_0's multi_logloss: 0.525485
# [647]	valid_0's multi_logloss: 0.525569
# [648]	valid_0's multi_logloss: 0.525601
# [649]	valid_0's multi_logloss: 0.525743
# [650]	valid_0's multi_logloss: 0.52571
# [651]	valid_0's multi_logloss: 0.525901
# [652]	valid_0's multi_logloss: 0.526198
# [653]	valid_0's multi_logloss: 0.526362
# [654]	valid_0's multi_logloss: 0.52652
# [655]	valid_0's multi_logloss: 0.526425
# [656]	valid_0's multi_logloss: 0.526505
# [657]	valid_0's multi_logloss: 0.526703
# [658]	valid_0's multi_logloss: 0.526756
# [659]	valid_0's multi_logloss: 0.526844
# [660]	valid_0's multi_logloss: 0.526999
# [661]	valid_0's multi_logloss: 0.526981
# [662]	valid_0's multi_logloss: 0.526909
# [663]	valid_0's multi_logloss: 0.527092
# [664]	valid_0's multi_logloss: 0.527017
# [665]	valid_0's multi_logloss: 0.526972
# [666]	valid_0's multi_logloss: 0.527123
# [667]	valid_0's multi_logloss: 0.527014
# [668]	valid_0's multi_logloss: 0.526945
# [669]	valid_0's multi_logloss: 0.527052
# [670]	valid_0's multi_logloss: 0.527063
# [671]	valid_0's multi_logloss: 0.527015
# [672]	valid_0's multi_logloss: 0.527035
# [673]	valid_0's multi_logloss: 0.527302
# [674]	valid_0's multi_logloss: 0.527659
# [675]	valid_0's multi_logloss: 0.527829
# [676]	valid_0's multi_logloss: 0.528152
# [677]	valid_0's multi_logloss: 0.527974
# [678]	valid_0's multi_logloss: 0.527817
# [679]	valid_0's multi_logloss: 0.527871
# [680]	valid_0's multi_logloss: 0.527859
# [681]	valid_0's multi_logloss: 0.528003
# [682]	valid_0's multi_logloss: 0.52805
# [683]	valid_0's multi_logloss: 0.52819
# [684]	valid_0's multi_logloss: 0.528287
# [685]	valid_0's multi_logloss: 0.528356
# [686]	valid_0's multi_logloss: 0.528374
# [687]	valid_0's multi_logloss: 0.528334
# [688]	valid_0's multi_logloss: 0.528275
# [689]	valid_0's multi_logloss: 0.528413
# [690]	valid_0's multi_logloss: 0.528322
# [691]	valid_0's multi_logloss: 0.528436
# [692]	valid_0's multi_logloss: 0.528479
# [693]	valid_0's multi_logloss: 0.528468
# [694]	valid_0's multi_logloss: 0.52854
# [695]	valid_0's multi_logloss: 0.528661
# [696]	valid_0's multi_logloss: 0.528875
# [697]	valid_0's multi_logloss: 0.52909
# [698]	valid_0's multi_logloss: 0.529265
# [699]	valid_0's multi_logloss: 0.529278
# [700]	valid_0's multi_logloss: 0.529475
# [767]	valid_0's multi_logloss: 0.53529
# [768]	valid_0's multi_logloss: 0.535442
# [769]	valid_0's multi_logloss: 0.535393
# [770]	valid_0's multi_logloss: 0.535441
# [771]	valid_0's multi_logloss: 0.535487
# [772]	valid_0's multi_logloss: 0.535468
# [773]	valid_0's multi_logloss: 0.535487
# [774]	valid_0's multi_logloss: 0.535483
# [775]	valid_0's multi_logloss: 0.535509
# [776]	valid_0's multi_logloss: 0.535675
# [777]	valid_0's multi_logloss: 0.535602
# [778]	valid_0's multi_logloss: 0.535567
# [779]	valid_0's multi_logloss: 0.535635
# [780]	valid_0's multi_logloss: 0.535605
# [781]	valid_0's multi_logloss: 0.535625
# [782]	valid_0's multi_logloss: 0.535636
# [783]	valid_0's multi_logloss: 0.53562
# [784]	valid_0's multi_logloss: 0.535542
# [785]	valid_0's multi_logloss: 0.535369
# [786]	valid_0's multi_logloss: 0.535361
# [787]	valid_0's multi_logloss: 0.535182
# [788]	valid_0's multi_logloss: 0.535091
# [789]	valid_0's multi_logloss: 0.535386
# [790]	valid_0's multi_logloss: 0.535494
# [791]	valid_0's multi_logloss: 0.535728
# [792]	valid_0's multi_logloss: 0.535858
# [793]	valid_0's multi_logloss: 0.535988
# [794]	valid_0's multi_logloss: 0.536036
# [795]	valid_0's multi_logloss: 0.536161
# [796]	valid_0's multi_logloss: 0.536113
# [797]	valid_0's multi_logloss: 0.536196
# [798]	valid_0's multi_logloss: 0.536436
# [799]	valid_0's multi_logloss: 0.536529
# [800]	valid_0's multi_logloss: 0.53659
# [801]	valid_0's multi_logloss: 0.536601
# [802]	valid_0's multi_logloss: 0.536553
# [803]	valid_0's multi_logloss: 0.53672
# [804]	valid_0's multi_logloss: 0.536731
# [805]	valid_0's multi_logloss: 0.537002
# [806]	valid_0's multi_logloss: 0.537185
# [807]	valid_0's multi_logloss: 0.537353
# [808]	valid_0's multi_logloss: 0.537563
# [809]	valid_0's multi_logloss: 0.537834
# [810]	valid_0's multi_logloss: 0.537994
# [811]	valid_0's multi_logloss: 0.538285
# [812]	valid_0's multi_logloss: 0.538529
# [813]	valid_0's multi_logloss: 0.538498
# [814]	valid_0's multi_logloss: 0.538531
# [815]	valid_0's multi_logloss: 0.538461
# [816]	valid_0's multi_logloss: 0.538474
# [817]	valid_0's multi_logloss: 0.538381
# [818]	valid_0's multi_logloss: 0.538294
# [819]	valid_0's multi_logloss: 0.538246
# [820]	valid_0's multi_logloss: 0.53819
# [821]	valid_0's multi_logloss: 0.538237
# [822]	valid_0's multi_logloss: 0.538271
# [823]	valid_0's multi_logloss: 0.53823
# [824]	valid_0's multi_logloss: 0.538318
# [825]	valid_0's multi_logloss: 0.538413
# [826]	valid_0's multi_logloss: 0.53851
# [827]	valid_0's multi_logloss: 0.538696
# [828]	valid_0's multi_logloss: 0.538772
# [829]	valid_0's multi_logloss: 0.538843
# [830]	valid_0's multi_logloss: 0.53885
# [831]	valid_0's multi_logloss: 0.538981
# [832]	valid_0's multi_logloss: 0.539019
# [833]	valid_0's multi_logloss: 0.539213
# [834]	valid_0's multi_logloss: 0.539235
# [835]	valid_0's multi_logloss: 0.539265
# [836]	valid_0's multi_logloss: 0.539458
# [837]	valid_0's multi_logloss: 0.539734
# [838]	valid_0's multi_logloss: 0.54012
# [839]	valid_0's multi_logloss: 0.540316
# [840]	valid_0's multi_logloss: 0.540517
# [841]	valid_0's multi_logloss: 0.540696
# [842]	valid_0's multi_logloss: 0.540886
# [843]	valid_0's multi_logloss: 0.540928
# [844]	valid_0's multi_logloss: 0.540921
# [845]	valid_0's multi_logloss: 0.541056
# [846]	valid_0's multi_logloss: 0.541239
# [847]	valid_0's multi_logloss: 0.541317
# [848]	valid_0's multi_logloss: 0.541472
# [849]	valid_0's multi_logloss: 0.541619
# [850]	valid_0's multi_logloss: 0.541793
# [851]	valid_0's multi_logloss: 0.541917
# [852]	valid_0's multi_logloss: 0.541975
# [853]	valid_0's multi_logloss: 0.54199
# [854]	valid_0's multi_logloss: 0.541968
# [855]	valid_0's multi_logloss: 0.542229
# [856]	valid_0's multi_logloss: 0.542241
# [857]	valid_0's multi_logloss: 0.54252
# [858]	valid_0's multi_logloss: 0.542776
# [859]	valid_0's multi_logloss: 0.543073
# [860]	valid_0's multi_logloss: 0.543245
# [861]	valid_0's multi_logloss: 0.543446
# [862]	valid_0's multi_logloss: 0.543504
# [863]	valid_0's multi_logloss: 0.543649
# [864]	valid_0's multi_logloss: 0.543728
# [865]	valid_0's multi_logloss: 0.543673
# [866]	valid_0's multi_logloss: 0.543687
# [867]	valid_0's multi_logloss: 0.543912
# [868]	valid_0's multi_logloss: 0.543951
# [869]	valid_0's multi_logloss: 0.544121
# [870]	valid_0's multi_logloss: 0.54427
# [871]	valid_0's multi_logloss: 0.544349
# [872]	valid_0's multi_logloss: 0.544542
# [873]	valid_0's multi_logloss: 0.544581
# [874]	valid_0's multi_logloss: 0.544557
# [875]	valid_0's multi_logloss: 0.544638
# [876]	valid_0's multi_logloss: 0.544584
# [877]	valid_0's multi_logloss: 0.544711
# [878]	valid_0's multi_logloss: 0.544871
# [879]	valid_0's multi_logloss: 0.544908
# [880]	valid_0's multi_logloss: 0.544961
# [881]	valid_0's multi_logloss: 0.544962
# [882]	valid_0's multi_logloss: 0.545014
# [883]	valid_0's multi_logloss: 0.545048
# [884]	valid_0's multi_logloss: 0.545042
# [885]	valid_0's multi_logloss: 0.545221
# [886]	valid_0's multi_logloss: 0.545392
# [887]	valid_0's multi_logloss: 0.545447
# [888]	valid_0's multi_logloss: 0.545722
# [889]	valid_0's multi_logloss: 0.545788
# [890]	valid_0's multi_logloss: 0.545935
# [891]	valid_0's multi_logloss: 0.545996
# [892]	valid_0's multi_logloss: 0.546074
# [893]	valid_0's multi_logloss: 0.546287
# [894]	valid_0's multi_logloss: 0.546415
# [895]	valid_0's multi_logloss: 0.546586
# [896]	valid_0's multi_logloss: 0.546736
# [897]	valid_0's multi_logloss: 0.546671
# [898]	valid_0's multi_logloss: 0.546684
# [899]	valid_0's multi_logloss: 0.546564
# [900]	valid_0's multi_logloss: 0.546467
# [901]	valid_0's multi_logloss: 0.546438
# [902]	valid_0's multi_logloss: 0.546598
# [903]	valid_0's multi_logloss: 0.546646
# [904]	valid_0's multi_logloss: 0.546669
# [905]	valid_0's multi_logloss: 0.546851
# [906]	valid_0's multi_logloss: 0.547033
# [907]	valid_0's multi_logloss: 0.54724
# [908]	valid_0's multi_logloss: 0.547436
# [909]	valid_0's multi_logloss: 0.547515
# [910]	valid_0's multi_logloss: 0.547636
# [911]	valid_0's multi_logloss: 0.547671
# [912]	valid_0's multi_logloss: 0.547773
# [913]	valid_0's multi_logloss: 0.547961
# [914]	valid_0's multi_logloss: 0.548216
# [915]	valid_0's multi_logloss: 0.548446
# [916]	valid_0's multi_logloss: 0.548573
# [917]	valid_0's multi_logloss: 0.548735
# [918]	valid_0's multi_logloss: 0.548928
# [919]	valid_0's multi_logloss: 0.549071
# [920]	valid_0's multi_logloss: 0.54923
# [921]	valid_0's multi_logloss: 0.549153
# [922]	valid_0's multi_logloss: 0.549242
# [923]	valid_0's multi_logloss: 0.549333
# [924]	valid_0's multi_logloss: 0.549378
# [925]	valid_0's multi_logloss: 0.549353
# [926]	valid_0's multi_logloss: 0.549426
# [927]	valid_0's multi_logloss: 0.549596
# [928]	valid_0's multi_logloss: 0.549707
# [929]	valid_0's multi_logloss: 0.549883
# [930]	valid_0's multi_logloss: 0.550031
# [931]	valid_0's multi_logloss: 0.550142
# [932]	valid_0's multi_logloss: 0.550256
# [933]	valid_0's multi_logloss: 0.550271
# [934]	valid_0's multi_logloss: 0.550348
# [935]	valid_0's multi_logloss: 0.550441
# [936]	valid_0's multi_logloss: 0.550666
# [937]	valid_0's multi_logloss: 0.550657
# [938]	valid_0's multi_logloss: 0.550671
# [939]	valid_0's multi_logloss: 0.550697
# [940]	valid_0's multi_logloss: 0.550725
# [941]	valid_0's multi_logloss: 0.550808
# [942]	valid_0's multi_logloss: 0.550731
# [943]	valid_0's multi_logloss: 0.550879
# [944]	valid_0's multi_logloss: 0.550828
# [945]	valid_0's multi_logloss: 0.550947
# [946]	valid_0's multi_logloss: 0.550901
# [947]	valid_0's multi_logloss: 0.550918
# [948]	valid_0's multi_logloss: 0.551032
# [949]	valid_0's multi_logloss: 0.55109
# [950]	valid_0's multi_logloss: 0.551193
# [951]	valid_0's multi_logloss: 0.551251
# [952]	valid_0's multi_logloss: 0.551315
# [953]	valid_0's multi_logloss: 0.551391
# [954]	valid_0's multi_logloss: 0.551495
# [955]	valid_0's multi_logloss: 0.551526
# [956]	valid_0's multi_logloss: 0.551609
# [957]	valid_0's multi_logloss: 0.551699
# [958]	valid_0's multi_logloss: 0.551726
# [959]	valid_0's multi_logloss: 0.551767
# [960]	valid_0's multi_logloss: 0.551822
# [961]	valid_0's multi_logloss: 0.551772
# [962]	valid_0's multi_logloss: 0.551814
# [963]	valid_0's multi_logloss: 0.551704
# [964]	valid_0's multi_logloss: 0.551662
# [965]	valid_0's multi_logloss: 0.551645
# [966]	valid_0's multi_logloss: 0.551668
# [1032]	valid_0's multi_logloss: 0.556993
# [1033]	valid_0's multi_logloss: 0.5571
# [1034]	valid_0's multi_logloss: 0.55715
# [1035]	valid_0's multi_logloss: 0.557186
# [1036]	valid_0's multi_logloss: 0.557237
# [1037]	valid_0's multi_logloss: 0.557381
# [1038]	valid_0's multi_logloss: 0.55765
# [1039]	valid_0's multi_logloss: 0.557927
# [1040]	valid_0's multi_logloss: 0.558067
# [1041]	valid_0's multi_logloss: 0.558264
# [1042]	valid_0's multi_logloss: 0.55828
# [1043]	valid_0's multi_logloss: 0.558265
# [1044]	valid_0's multi_logloss: 0.55842
# [1045]	valid_0's multi_logloss: 0.55852
# [1046]	valid_0's multi_logloss: 0.558693
# [1047]	valid_0's multi_logloss: 0.558809
# [1048]	valid_0's multi_logloss: 0.558843
# [1049]	valid_0's multi_logloss: 0.558993
# [1050]	valid_0's multi_logloss: 0.559217
# [1051]	valid_0's multi_logloss: 0.559441
# [1052]	valid_0's multi_logloss: 0.559711
# [1053]	valid_0's multi_logloss: 0.559727
# [1054]	valid_0's multi_logloss: 0.559904
# [1055]	valid_0's multi_logloss: 0.560028
# [1056]	valid_0's multi_logloss: 0.560105
# [1057]	valid_0's multi_logloss: 0.560223
# [1058]	valid_0's multi_logloss: 0.560314
# [1059]	valid_0's multi_logloss: 0.560381
# [1060]	valid_0's multi_logloss: 0.560506
# [1061]	valid_0's multi_logloss: 0.560629
# [1062]	valid_0's multi_logloss: 0.560772
# [1063]	valid_0's multi_logloss: 0.560951
# [1064]	valid_0's multi_logloss: 0.561075
# [1065]	valid_0's multi_logloss: 0.561129
# [1066]	valid_0's multi_logloss: 0.561273
# [1067]	valid_0's multi_logloss: 0.561449
# [1068]	valid_0's multi_logloss: 0.561566
# [1069]	valid_0's multi_logloss: 0.561725
# [1070]	valid_0's multi_logloss: 0.56187
# [1071]	valid_0's multi_logloss: 0.561984
# [1072]	valid_0's multi_logloss: 0.562139
# [1073]	valid_0's multi_logloss: 0.562158
# [1074]	valid_0's multi_logloss: 0.562189
# [1075]	valid_0's multi_logloss: 0.562274
# [1076]	valid_0's multi_logloss: 0.562295
# [1077]	valid_0's multi_logloss: 0.562218
# [1078]	valid_0's multi_logloss: 0.56217
# [1079]	valid_0's multi_logloss: 0.562144
# [1080]	valid_0's multi_logloss: 0.562217
# [1081]	valid_0's multi_logloss: 0.562222
# [1082]	valid_0's multi_logloss: 0.562147
# [1083]	valid_0's multi_logloss: 0.562182
# [1084]	valid_0's multi_logloss: 0.562242
# [1085]	valid_0's multi_logloss: 0.562351
# [1086]	valid_0's multi_logloss: 0.562496
# [1087]	valid_0's multi_logloss: 0.562652
# [1088]	valid_0's multi_logloss: 0.562768
# [1089]	valid_0's multi_logloss: 0.56281
# [1090]	valid_0's multi_logloss: 0.56285
# [1091]	valid_0's multi_logloss: 0.562926
# [1092]	valid_0's multi_logloss: 0.562972
# [1093]	valid_0's multi_logloss: 0.562859
# [1094]	valid_0's multi_logloss: 0.562819
# [1095]	valid_0's multi_logloss: 0.562753
# [3713]	valid_0's multi_logloss: 0.755007
# [3714]	valid_0's multi_logloss: 0.755074
# [3715]	valid_0's multi_logloss: 0.755129
# [3716]	valid_0's multi_logloss: 0.755205
# [3717]	valid_0's multi_logloss: 0.755225
# [3718]	valid_0's multi_logloss: 0.755277
# [3719]	valid_0's multi_logloss: 0.75533
# [3720]	valid_0's multi_logloss: 0.755361
# [3721]	valid_0's multi_logloss: 0.755378
# [3722]	valid_0's multi_logloss: 0.755355
# [3723]	valid_0's multi_logloss: 0.75536
# [3724]	valid_0's multi_logloss: 0.755359
# [3725]	valid_0's multi_logloss: 0.755464
# [3726]	valid_0's multi_logloss: 0.755528
# [3727]	valid_0's multi_logloss: 0.755631
# [3728]	valid_0's multi_logloss: 0.755735
# [3729]	valid_0's multi_logloss: 0.755797
# [3730]	valid_0's multi_logloss: 0.755867
# [3731]	valid_0's multi_logloss: 0.755954
# [3732]	valid_0's multi_logloss: 0.756038
# [3733]	valid_0's multi_logloss: 0.756047
# [3734]	valid_0's multi_logloss: 0.756026
# [3735]	valid_0's multi_logloss: 0.756024
# [3736]	valid_0's multi_logloss: 0.755967
# [3737]	valid_0's multi_logloss: 0.756039
# [3738]	valid_0's multi_logloss: 0.756034
# [3739]	valid_0's multi_logloss: 0.756004
# [3740]	valid_0's multi_logloss: 0.756014
# [3741]	valid_0's multi_logloss: 0.756038
# [3742]	valid_0's multi_logloss: 0.756041
# [3743]	valid_0's multi_logloss: 0.756044
# [3744]	valid_0's multi_logloss: 0.756048
# [3745]	valid_0's multi_logloss: 0.756143
# [3746]	valid_0's multi_logloss: 0.756225
# [3747]	valid_0's multi_logloss: 0.75632
# [3748]	valid_0's multi_logloss: 0.756392
# [3749]	valid_0's multi_logloss: 0.756457
# [3750]	valid_0's multi_logloss: 0.756526
# [3751]	valid_0's multi_logloss: 0.756557
# [3752]	valid_0's multi_logloss: 0.756614
# [3753]	valid_0's multi_logloss: 0.756603
# [3754]	valid_0's multi_logloss: 0.756623
# [3755]	valid_0's multi_logloss: 0.756628
# [3756]	valid_0's multi_logloss: 0.756612
# [3757]	valid_0's multi_logloss: 0.756684
# [3758]	valid_0's multi_logloss: 0.75676
# [3759]	valid_0's multi_logloss: 0.75686
# [3760]	valid_0's multi_logloss: 0.756931
# [3761]	valid_0's multi_logloss: 0.756925
# [3762]	valid_0's multi_logloss: 0.756924
# [3763]	valid_0's multi_logloss: 0.756968
# [3764]	valid_0's multi_logloss: 0.757042
# [3765]	valid_0's multi_logloss: 0.757027
# [3766]	valid_0's multi_logloss: 0.757013
# [3767]	valid_0's multi_logloss: 0.757008
# [3768]	valid_0's multi_logloss: 0.756995
# [3769]	valid_0's multi_logloss: 0.75694
# [3770]	valid_0's multi_logloss: 0.756956
# [3771]	valid_0's multi_logloss: 0.756891
# [3772]	valid_0's multi_logloss: 0.756909
# [3773]	valid_0's multi_logloss: 0.75693
# [3774]	valid_0's multi_logloss: 0.756951
# [3775]	valid_0's multi_logloss: 0.756944
# [3776]	valid_0's multi_logloss: 0.756965
# [3777]	valid_0's multi_logloss: 0.756984
# [3778]	valid_0's multi_logloss: 0.757012
# [3779]	valid_0's multi_logloss: 0.757039
# [3780]	valid_0's multi_logloss: 0.757061
# [3781]	valid_0's multi_logloss: 0.75708
# [3782]	valid_0's multi_logloss: 0.75707
# [3783]	valid_0's multi_logloss: 0.757053
# [3784]	valid_0's multi_logloss: 0.757043
# [3785]	valid_0's multi_logloss: 0.757109
# [3786]	valid_0's multi_logloss: 0.757158
# [3787]	valid_0's multi_logloss: 0.757203
# [3788]	valid_0's multi_logloss: 0.757268
# [3789]	valid_0's multi_logloss: 0.757291
# [3790]	valid_0's multi_logloss: 0.75727
# [3791]	valid_0's multi_logloss: 0.75735
# [3792]	valid_0's multi_logloss: 0.757401
# [3793]	valid_0's multi_logloss: 0.757443
# [3794]	valid_0's multi_logloss: 0.757484
# [3795]	valid_0's multi_logloss: 0.757525
# [3796]	valid_0's multi_logloss: 0.757566
# [3797]	valid_0's multi_logloss: 0.757599
# [3798]	valid_0's multi_logloss: 0.757621
# [3799]	valid_0's multi_logloss: 0.757634
# [3800]	valid_0's multi_logloss: 0.757656
# [3801]	valid_0's multi_logloss: 0.757666
# [3802]	valid_0's multi_logloss: 0.757676
# [3803]	valid_0's multi_logloss: 0.757757
# [3804]	valid_0's multi_logloss: 0.757792
# [3805]	valid_0's multi_logloss: 0.757829
# [3806]	valid_0's multi_logloss: 0.757847
# [3807]	valid_0's multi_logloss: 0.757882
# [3808]	valid_0's multi_logloss: 0.757908
# [3809]	valid_0's multi_logloss: 0.757986
# [3810]	valid_0's multi_logloss: 0.758041
# [3811]	valid_0's multi_logloss: 0.758086
# [3812]	valid_0's multi_logloss: 0.758154
# [3813]	valid_0's multi_logloss: 0.758171
# [3814]	valid_0's multi_logloss: 0.758175
# [3815]	valid_0's multi_logloss: 0.758192
# [3816]	valid_0's multi_logloss: 0.758214
# [3817]	valid_0's multi_logloss: 0.758251
# [3818]	valid_0's multi_logloss: 0.758287
# [3819]	valid_0's multi_logloss: 0.758325
# [3820]	valid_0's multi_logloss: 0.758382
# [3821]	valid_0's multi_logloss: 0.75839
# [3822]	valid_0's multi_logloss: 0.758453
# [3823]	valid_0's multi_logloss: 0.758523
# [3824]	valid_0's multi_logloss: 0.758531
# [3825]	valid_0's multi_logloss: 0.758621
# [3826]	valid_0's multi_logloss: 0.758706
# [3827]	valid_0's multi_logloss: 0.758768
# [3828]	valid_0's multi_logloss: 0.758852
# [3829]	valid_0's multi_logloss: 0.758872
# [3830]	valid_0's multi_logloss: 0.758913
# [3831]	valid_0's multi_logloss: 0.758947
# [3832]	valid_0's multi_logloss: 0.759003
# [3833]	valid_0's multi_logloss: 0.758979
# [3834]	valid_0's multi_logloss: 0.759065
# [3835]	valid_0's multi_logloss: 0.759078
# [3836]	valid_0's multi_logloss: 0.759081
# [3837]	valid_0's multi_logloss: 0.759109
# [3838]	valid_0's multi_logloss: 0.759136
# [3839]	valid_0's multi_logloss: 0.759164
# [3840]	valid_0's multi_logloss: 0.759188
# [3841]	valid_0's multi_logloss: 0.759162
# [3842]	valid_0's multi_logloss: 0.759192
# [3843]	valid_0's multi_logloss: 0.75917
# [3844]	valid_0's multi_logloss: 0.759186
# [3845]	valid_0's multi_logloss: 0.75918
# [3846]	valid_0's multi_logloss: 0.75921
# [3847]	valid_0's multi_logloss: 0.759194
# [3848]	valid_0's multi_logloss: 0.759178
# [3849]	valid_0's multi_logloss: 0.759127
# [3850]	valid_0's multi_logloss: 0.759114
# [3851]	valid_0's multi_logloss: 0.759122
# [3852]	valid_0's multi_logloss: 0.759097
# [3853]	valid_0's multi_logloss: 0.759102
# [3854]	valid_0's multi_logloss: 0.759146
# [3855]	valid_0's multi_logloss: 0.759191
# [3856]	valid_0's multi_logloss: 0.75926
# [3857]	valid_0's multi_logloss: 0.75932
# [3858]	valid_0's multi_logloss: 0.759346
# [3859]	valid_0's multi_logloss: 0.759386
# [3860]	valid_0's multi_logloss: 0.759425
# [3861]	valid_0's multi_logloss: 0.759446
# [3862]	valid_0's multi_logloss: 0.75947
# [3863]	valid_0's multi_logloss: 0.759508
# [3864]	valid_0's multi_logloss: 0.759557
# [3865]	valid_0's multi_logloss: 0.759524
# [3866]	valid_0's multi_logloss: 0.759517
# [3867]	valid_0's multi_logloss: 0.759517
# [3868]	valid_0's multi_logloss: 0.759511
# [3869]	valid_0's multi_logloss: 0.759505
# [3870]	valid_0's multi_logloss: 0.759472
# [3871]	valid_0's multi_logloss: 0.759466
# [3872]	valid_0's multi_logloss: 0.759464
# [3873]	valid_0's multi_logloss: 0.759426
# [3874]	valid_0's multi_logloss: 0.759446
# [3875]	valid_0's multi_logloss: 0.759408
# [3876]	valid_0's multi_logloss: 0.75939
# [3877]	valid_0's multi_logloss: 0.759485
# [3878]	valid_0's multi_logloss: 0.759525
# [3879]	valid_0's multi_logloss: 0.759617
# [3880]	valid_0's multi_logloss: 0.759711
# [3881]	valid_0's multi_logloss: 0.759711
# [3882]	valid_0's multi_logloss: 0.759686
# [3883]	valid_0's multi_logloss: 0.759662
# [3884]	valid_0's multi_logloss: 0.759662
# [3885]	valid_0's multi_logloss: 0.759582
# [3886]	valid_0's multi_logloss: 0.759506
# [3887]	valid_0's multi_logloss: 0.759419
# [3888]	valid_0's multi_logloss: 0.759348
# [3889]	valid_0's multi_logloss: 0.759338
# [3890]	valid_0's multi_logloss: 0.75933
# [3891]	valid_0's multi_logloss: 0.759335
# [3892]	valid_0's multi_logloss: 0.759325
# [3893]	valid_0's multi_logloss: 0.75932
# [3894]	valid_0's multi_logloss: 0.75932
# [3895]	valid_0's multi_logloss: 0.759315
# [3896]	valid_0's multi_logloss: 0.759273
# [3897]	valid_0's multi_logloss: 0.75925
# [3898]	valid_0's multi_logloss: 0.759244
# [3899]	valid_0's multi_logloss: 0.759263
# [3900]	valid_0's multi_logloss: 0.759241
# [3901]	valid_0's multi_logloss: 0.759301
# [3902]	valid_0's multi_logloss: 0.759357
# [3903]	valid_0's multi_logloss: 0.759378
# [3904]	valid_0's multi_logloss: 0.759448
